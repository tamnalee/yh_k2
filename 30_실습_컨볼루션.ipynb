# %% [markdown]
# ## Exercise 3
# 1. 실습 1번
#
#  손글씨 숫자 MNIST 를 가지고, 99.8% accuracy 보다 크게 나오도록,  convolutional layer 는 딱 1개만 사용하고,  MaxPooling 2D도 한 1개만 사용한다. 그리고 epochs는 20으로 셋팅하고,  accuracy 가 위의 수치를 만족하면, "Reached 99.8% accuracy so cancelling training!"를 출력하고, 학습을 멈추도록 모델링과 컴파일을 하시오.

# %%
import tensorflow as tf

# %%
def train_mnist_conv():
    # YOUR CODE STARTS HERE
    
    # YOUR CODE ENDS HERE

    mnist = tf.keras.datasets.mnist
    (training_images, training_labels), (test_images, test_labels) = mnist.load_data()
    # YOUR CODE STARTS HERE
    
    # YOUR CODE ENDS HERE

    model = tf.keras.models.Sequential([
            # YOUR CODE STARTS HERE
            
            # YOUR CODE ENDS HERE
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    # model fitting
    history = model.fit(
        # YOUR CODE STARTS HERE
        
        # YOUR CODE ENDS HERE
    )
    # model fitting
    return history.epoch, history.history['accuracy'][-1]

# %%
_, _ = train_mnist_conv()

# %% [markdown]
# 2. 실습 2번
#
#  val_accuracy 가 96% 이상이면 학습을 멈추도록 코드를 수정하여 실행하시오
